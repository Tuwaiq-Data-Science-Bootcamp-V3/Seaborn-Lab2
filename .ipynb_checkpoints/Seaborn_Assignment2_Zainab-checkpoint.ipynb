# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips_dataset = sns.load_dataset('tips')
tips_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
# write your code here ^_^
sns.set(style='whitegrid')
sns.histplot(tips_dataset, x="tip", hue="day", element="step")
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Count'>

# %% [markdown]
# ## Q2.1 Write your top three findings
# - Saturday has the highest number of tips.
# - High tips value (8 and 10) only given on Saturday.
# - Friday has the least number of tips.

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
# write your code here ^_^

plt.figure(figsize=(7, 5))

sns.set(style='whitegrid')
sns.displot(tips_dataset, x='day', hue='sex', multiple='dodge', shrink=0.75, palette='Set1', hue_order=["Female","Male"]);

plt.xlabel('Day')
plt.ylabel('Count')
plt.title('Distribution of Tips');

# %% [markdown]
# ## Q3.1 Write your top three findings
# - Friday has the least number of tips for both males and females.
# - Males give tips much more than females on weekends (Saturday and Sunday).
# - On Thursday, the females give tips more than the males.

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
# write your code here ^_^
plt.figure(figsize=(7, 5))

sns.set(style='darkgrid', font_scale=1.25)
sns.ecdfplot(tips_dataset, x="tip", hue="time", palette="summer", linewidth=3)
# Out:
# <AxesSubplot: xlabel='tip', ylabel='Proportion'>

# %% [markdown]
# ## Q4.1 Write your top three findings
# - Most tips (80%) have a value of 4 or less.
# - A high tips value (from 7 to 10) only given at dinner.
# - half of the dataset for both lunch and dinner have a low tip value (3 and less).

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
# write your code here ^_^
plt.figure(figsize=(7,5))
sns.set(style='whitegrid')
sns.boxplot(
    x="day", 
    y="tip",
    hue="sex",
    hue_order=["Female","Male"],
    palette="Paired", 
    linewidth=2.5,
    data=tips_dataset)

plt.legend(loc='upper right', title='sex')

# %% [markdown]
# ## Q5.1 Write your top three findings
# - Most tips values ranges from 2 to 4.
# - There are many outliers tips values by males in saturday.
# - Females gives less tips value than males.

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
# write your code here ^_^
sns.violinplot(data=tips_dataset, 
               x="time", 
               y="tip", 
               inner="quartile",
               split=True,
               hue="sex",
               hue_order=["Female","Male"],
               palette="Pastel1", 
               linewidth=2)
plt.legend(loc='upper left', title='sex')

# %% [markdown]
# ## Q6.1 Write your top three findings
# - The tip amount for dinner reaches more than 10, while for lunch it is 8 or less.
# - The most given tip amount for both lunch and dinner ranges from 2 to 3.
# - Males gives tips more than females.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
# write your code here ^_^
sns.swarmplot(
    data=tips_dataset,
    x="time",
    y="total_bill",
    hue="size"
)
# Out:
# <AxesSubplot: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ## Q7.1 Write your top three findings
# - When the size (number of people) in the table is large, the total bill increases.
# - Most of dataset records for tables contains "2-3" people (The size).
# - People rarely go out to eat alone compared to going out with two or more people.

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
# write your code here ^_^
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

sns.heatmap(tips_dataset.corr(), annot=True, cmap= 'RdBu',vmin=-1, vmax=1)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Q8.1 Write your top three findings
# - The total bill have strong correlation with the tip value.
# - The size have strong correlation with the total bill, but a Moderate correlation with the tip.
# - All numeric columns have positive relations, either a strong or Moderate correlation.
