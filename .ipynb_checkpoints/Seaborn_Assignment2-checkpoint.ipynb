# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns

# %%
tips_dataset = sns.load_dataset('tips')

# %%
tips_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
# write your code here ^_^
plt.figure(figsize=(15,8))
sns.histplot(
    tips_dataset,
    x="tip",
    hue ="day",
    element='step',
    multiple="stack",
    alpha=0.8,
    color ="whitegrid");

# %% [markdown]
# ## Q2.1 Write your top three findings
# - the tip varies from person to person and according to the quality of service
# - if we notice the drawing,most of those who pay onlu 3 , because the amount is small and everyone has it
# - it is rare for anyone to donate more than 5$

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
# write your code here ^_^
hu = ['Female','Male']
sns.displot(
    data=tips_dataset,
    x ='day',hue='sex',
    multiple ='dodge',
    hue_order=hu,
    color ="Set1",
    shrink =0.4
);

# %% [markdown]
# ## Q3.1 Write your top three findings
# - the most of donors are male
# - fewer male donors
# - friday the lowest day to donate

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
# write your code here ^_^
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.ecdfplot(
    data =tips_dataset,
    x='tip',
    hue='time',
    lw=3,
    color ='summer'
);

# %% [markdown]
# ## Q4.1 Write your top three findings
# - The ECDF plot shows the cumulative distribution of tip amounts, with the x-axis representing the tip amount and the y-axis representing the proportion of tips less than or equal to that amount.
# - majority of the tips are less than or equal to $5
# - split by time shows that the distribution of tips is similar during lunch and dinner

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
# write your code here ^_^
sns.set_style('whitegrid')
sns.boxplot(data=tips_dataset, x="day", y="tip", hue="sex", palette="Paired", hue_order=["Female", "Male"], linewidth=2.5);

# %% [markdown]
# ## Q5.1 Write your top three findings
# - shows the distribution of tip amounts across different days
# - amount is higher on Saturdays and Sundays
# - plit by sex reveals that on average, male customers tend to give slightly higher tips than female

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
# write your code here ^_^
sns.violinplot(
    data=tips_dataset, 
    x="time", 
    y="tip", 
    hue="sex",
    hue_order=["Female", "Male"],
    inner='quartiles',
    palette ='Pastel1',
    linewidth=2,
);
plt.legend(loc ='upper left')

# %% [markdown]
# ## Q6.1 Write your top three findings
# -  shows the distribution of tip amounts across different times
# -  split by sex reveals that on average, male customers tend to give slightly higher tips than female
# - The distribution of tips is similar during lunch and dinner, with a slightly wider range of tip amounts during dinner.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
# write your code here ^_^
plt.figure(figsize=(10,8)) 

sns.swarmplot(
    x="time",
    y="total_bill", 
    hue="size", 
    data=tips_dataset
);

# %% [markdown]
# ## Q7.1 Write your top three findings
# - The similarity in the distribution of tips across lunch and dinner indicates that customers may be tipping based on similar factors
# - The wider range of tip amounts during dinner could be due to a variety of factors, such as offerings
# - The wider range of tip amounts during dinner may also indicate that there is a higher variability in the quality of service during dinner

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
# write your code here ^_^



corr = tips_dataset.corr()
plt.figure(figsize=(8,5))
sns.heatmap(corr, cmap='RdBu', annot=True, vmin=-1, vmax=1);
plt.title("correlations Heatmap")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_15076\2165966931.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = tips_dataset.corr()
# Text(0.5, 1.0, 'correlations Heatmap')

# %% [markdown]
# ## Q8.1 Write your top three findings
# - The correlation heatmap shows  between all numerical columns in the tips dataset.
# - The strongest positive correlation exists between total_bill and tip, indicating that customers tend to give higher tips when the bill amount is higher
# - The tip will be less if the service quality is bad .
