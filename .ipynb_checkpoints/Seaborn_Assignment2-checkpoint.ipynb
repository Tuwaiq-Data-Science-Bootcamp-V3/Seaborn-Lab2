# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns

# %%
tips_dataset = sns.load_dataset('tips')

# %%
tips_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
# write your code here ^_^



# Set style to 'whitegrid'
sns.set_style("whitegrid")

# Create a histogram with hue split by the 'day' column
sns.histplot(data=tips_dataset, x="tip", hue="day", element="step")

# Show the plot
plt.show()

# %% [markdown]
# ## Q2.1 Write your top three findings
# - In Sunday its the least tip and count.
# - Saturday is the most day tip and count while the max tip here is 10 and the max count is 20 if the is 3.
# - It shows there is high tips and count while the tip between 2 and 4 the count here is the highest through all days.

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
# write your code here ^_^

# Set the hue order
hue_order = ['Female', 'Male']

# Create a displot with hue split by the 'sex' column
sns.displot(data=tips_dataset, x="day", hue="sex", multiple="dodge", shrink=0.8, palette="Set1", hue_order=hue_order)

# Show the plot
plt.show()

# %% [markdown]
# ## Q3.1 Write your top three findings
# - The Male got the highest count through the days.
# - The Female in thursday is the highest in the count.
# -  Saturday is the max in count for the male

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
# write your code here ^_^
sns.set_style("darkgrid")

# Set the font scale to 1.25
sns.set(font_scale=1.25)

# Create an ECDF plot with hue split by the 'time' column
sns.ecdfplot(data=tips_dataset, x="tip", hue="time", color="summer", linewidth=3)

# Show the plot
plt.show()

# %% [markdown]
# ## Q4.1 Write your top three findings
# - What I see the tip increasing in dinner and lunch
# - theres no diffrent between the dinner and lunch through the tip and proprtion
# - maybe the the lunch time has the hieghst tip and proportion

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
# write your code here ^_^

# Set the style to 'whitegrid'
sns.set_style("whitegrid")

# Set the hue order
hue_order = ['Female', 'Male']

# Create a box plot with hue split by the 'sex' column
sns.boxplot(data=tips_dataset, x="day", y="tip", hue="sex", palette="Paired", hue_order=hue_order, linewidth=2.5)

# Show the plot
plt.show()

# %% [markdown]
# ## Q5.1 Write your top three findings
# - The Outlayers in saturday for the male is the most.
# - The male got the maximum tip through all days.
# - In Friday in the female boxplot there is outlayer in the minimum.

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
# write your code here ^_^
sns.violinplot(data=tips_dataset, x="time", y="tip", hue="sex", split=True, inner="quartiles", palette="Pastel1", hue_order=hue_order, linewidth=2)

# Set the legend's location to upper left
plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# ## Q6.1 Write your top three findings
# - In the dinner time the tips is high in both Male and Female.
# - The Lunch time Female gives the lowest tips.
# - In the both dinner and the lunch time the always the male gives the most tips.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
# write your code here ^_^
sns.swarmplot(data=tips_dataset, x="time", y="total_bill", hue="size")

# Show the plot
plt.show()

# %% [markdown]
# ## Q7.1 Write your top three findings
# - In dinner time the total bill is high.
# - The Lunch time is least in the total bill.
# - The size in the dinner time bigger than the Lunch time.

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
# write your code here ^_^

# Calculate the correlation matrix
correlation_matrix = tips_dataset.corr()

# Set the figure size
plt.figure(figsize=(8, 5))

# Create a correlation heatmap
sns.heatmap(correlation_matrix, cmap='RdBu', annot=True, vmin=-1, vmax=1)

# Show the plot
plt.show()
# Out:
# C:\Users\faris\AppData\Local\Temp\ipykernel_7312\1201897771.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = tips_dataset.corr()

# %% [markdown]
# ## Q8.1 Write your top three findings
# - The size and total bill show positive correlation
# - The tip and the size shows negative correlation
# - The tip and the total bill shows positive correlation
