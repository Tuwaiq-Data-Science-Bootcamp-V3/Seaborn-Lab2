# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
# write your code here ^_^
import seaborn as sns
sns.set()

# %%
tips_dataset = sns.load_dataset('tips')
tips_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
# Point 3 on this Q not that clear to me
sns.set_style('whitegrid')
ch1 =sns.displot(x='tip', data=tips_dataset, element='step')
sns.histplot(x='tip',hue='day', data=tips_dataset)
# The chart doesnot show with me so i used matplotlib to show it
plt.show(ch1)

# %% [markdown]
# ## Q2.1 Write your top three findings
# - Usually the tip is around 4
# - It is rare for the tip to reach $10. However, this may happen on holidays such as Saturday
# - The chance to tip increases during the weekend.

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
ch2 = sns.displot(x='day',hue='sex',hue_order=['Female','Male'],color='#a1856c', data=tips_dataset,multiple="dodge",shrink=0.6)
plt.show()

# %% [markdown]
# ## Q3.1 Write your top three findings
# - The number of men on weekends is double the number of women.
# - The numbers on Friday are very few
# - Women are active on regular days and less on weekends.

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
# Here to change the color of the background 
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
ch3 = sns.ecdfplot(x='tip',color='summer', data=tips_dataset,hue='time',lw=3)
plt.show(ch3)

# %% [markdown]
# ## Q4.1 Write your top three findings
# - The tip is not up to 10 except at dinner
# - They are close most of the time
# - People don't tip too much at lunchtime

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
sns.set(font_scale=1)
# I tried to change the color to paired but it doesnot work with me so i search and try to find a similar color using RGB
ch4 = sns.boxplot(x = 'day',y = 'tip',linewidth=2.5,hue = 'sex',hue_order=['Female','Male'],data=tips_dataset,color='#e31a1c');
sns.set_style('whitegrid')
plt.show(ch4)

# %% [markdown]
# ## Q5.1 Write your top three findings
# - Usually on Sunday both sexes pay a $4 tip
# - Men usually tip more most days
# - There is a significant difference in tips between the sexes on Thursday

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
sns.violinplot(
    data=tips_dataset, 
    x="time", 
    y="tip", 
    hue="sex",
    # Here i used alt to change the color and it is work instead of (color)
    alt="pastell",
    split="sex",
    hue_order=['Female','Male'],
    inner= 'quartiles',
    linewidth=2,
    
)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Q6.1 Write your top three findings
# - The tip is usually between 2 and 4 most of the time
# - Tipping value decreases after 4
# - Men pay a higher amount in tips than women

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
sns.swarmplot(
    x="time",
    y="total_bill", 
    hue="size", 
    data=tips_dataset
)
plt.show()

# %% [markdown]
# ## Q7.1 Write your top three findings
# - Most of customrs comes as couble
# - It is very rarly that table to be come full
# - The chance of getting a higher tip increases as the number of people increases

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
plt.figure(figsize=(8,5))
corr_matrix = tips_dataset.corr()
sns.heatmap(corr_matrix, annot=True,vmin=-1,vmax=1,cmap="RdBu")
plt.show()

# %% [markdown]
# ## Q8.1 Write your top three findings
# - Most of the relationships between the columns are medium between 0.4 and 0.7 approximately
# - The highest correlation is between total_bill and tip
# - There is no low correlation between columns
