# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1: Import seaborn library

# %%
import seaborn as sns

# %%
tips_dataset = sns.load_dataset('tips')
tips_dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # Q2: Create a histogram, where the x-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the day column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the element argument over to step.

# %%
plt.figure(figsize=(15, 7))
sns.set_style('whitegrid')
sns.histplot(data=tips_dataset, x='tip', hue='day', element='step')
plt.xlabel('Tip')
plt.ylabel('Count')
plt.title('Tip Histogram')
plt.show()

# %% [markdown]
# ## Q2.1 Write your top three findings
# - Saturday recorded tip amount (3 - 3.5) are more common or frequent (20 times).
# - the highest tip amount = (9.5 - 10) recorded in Saturday.
# - Record on Friday the lowest frequency of tips.
# - Tips (0-2 , 2-4) recorded in all days.

# %% [markdown]
# # Q3: [Optional] Create a displot, where the x-axis represents the day column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Handle the overlapping columns by switching the multiple argument over to 'dodge'.
# - Shrink the bars down using shrink argument to have a nice gap between each of them.
# - Change the bars color to 'Set1'.
# - Reset the hue order to ['Female', 'Male'].

# %%
plt.figure(figsize=(15, 7))
sns.set_palette('Set1')
hue_order = ['Female', 'Male']
sns.displot(data=tips_dataset, x='day', hue='sex', multiple='dodge', shrink=0.8, hue_order=hue_order)
plt.title('Days by Gender')
plt.xlabel('Day')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## Q3.1 Write your top three findings
# - Female recorded trips in Thursdy more than male.
# - On Sunday, male pay 3 times more tips than female.
# - Friday scores the least tips.

# %% [markdown]
# # Q4: Create a ecdf plot, where the x-axis represents the tip column
# - Change the style to 'darkgrid'.
# - Change the font scale to 1.25.
# - Split the data out by the time column's categories. Hint: use hue argument.
# - Change the lines color to 'summer'.
# - Change the line width to 3.

# %%
plt.figure(figsize=(15, 7))
sns.set_style('darkgrid')
sns.set(font_scale=1.25)
sns.set_palette('summer')
sns.ecdfplot(data=tips_dataset, x='tip', hue='time', linewidth=3)
# plt.title()
# plt.xlabel()
# plt.ylabel()
plt.show()

# %% [markdown]
# ## Q4.1 Write your top three findings
# - Higher tip amounts are more frequently observed during dinner compared to lunch.
# - The rate of tips during the lunch time reaches approximately 6.5, while the rate of tips during the dinner time reaches 10.
# - The proportion increases with the increase in the tip.

# %% [markdown]
# # Q5: [Optional] Create a box plot, where the x-axis represents the day column and the y-axis represents the tip column
# - Change the style to 'whitegrid'.
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Change the bars color to 'Paired'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.5.

# %%
plt.figure(figsize=(15, 7))
sns.set_style('whitegrid')
sns.set_palette('Paired')
hue_order = ['Female', 'Male']
sns.boxplot(data=tips_dataset, x='day',y ='tip', hue='sex', linewidth=2.5, hue_order = hue_order)
# plt.title()
# plt.xlabel()
# plt.ylabel()
plt.show()

# %% [markdown]
# ## Q5.1 Write your top three findings
# - There is ifferences in the distribution of tip amounts across the days.
# - Based on outliers, in Satuerday the males given higher tip amounts.
# - Also, based on outliers, in Friday the females given lower tip amounts.
# - Most of the time, the maximum tip amount for male is higher than for female.

# %% [markdown]
# # Q6: Create a violin plot, where the x-axis represents the time column and the y-axis represents the tip column
# - Split the data out by the sex column's categories. Hint: use hue argument.
# - Split the violin so that each violin contains both sex column's categories. Hint: use split argument.
# - Change the shape of the inner part of the violin to 'quartiles'.
# - Change the violin color to 'Pastel1'.
# - Reset the hue order to ['Female', 'Male'].
# - Change the line width to 2.
# - Change the legend's location to The upper left.

# %%
plt.figure(figsize=(15, 7))
sns.set_palette('Pastel1')
hue_order = ['Female', 'Male']
sns.violinplot(data=tips_dataset, x='time', y = 'tip', hue='sex',split =True , inner='quartiles', linewidth=2, hue_order = hue_order)
# plt.title()
plt.xlabel('Time')
plt.ylabel('Tip')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Q6.1 Write your top three findings
# - The customers tend to give higher tips during dinner service compared to lunch service.
# - Females exhibiting a broader range of tip amounts and potentially giving higher tips on average during dinner.
# - Lower tip amounts are observed during lunch.
# - Males giving tips more than Females.

# %% [markdown]
# # Q7: [Optional] Create a swarm plot, where the x-axis represents the time column and the y-axis represents the total_bill column
# - Split the data out by the size column's categories. Hint: use hue argument.

# %%
plt.figure(figsize=(15, 7))
sns.swarmplot(data=tips_dataset, x='time', y = 'total_bill', hue='size')
# plt.title()
plt.xlabel('Time')
plt.ylabel('Total bill')
plt.show()

# %% [markdown]
# ## Q7.1 Write your top three findings
# - It appears that dinner tends to have higher total bill amounts compared to lunch.
# - Total bill in Dinner more than total bill in Lunch.
# - Size = 1 (number of persons) is very low at lunch and dinner.
# - The most total bill was between 10$ to 30$.

# %% [markdown]
# # Q8: Create a correlation heatmap
# - Adjust the figure's size to be (8,5).
# - Change the color map to 'RdBu'.
# - Add annotations to the heatmap.
# - Set the minimum value to be -1.
# - Set the maximum value to be 1.

# %%
plt.figure(figsize=(8, 5))
corr_matrix = tips_dataset.corr()
sns.heatmap(corr_matrix, cmap='RdBu', annot=True, vmin=-1, vmax=1)
plt.title("Correlation Heatmap")
plt.show()
# Out:
# /var/folders/t_/vym23x_97w3gcgcc4rq25fyc0000gn/T/ipykernel_9538/867774375.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = tips_dataset.corr()

# %% [markdown]
# ## Q8.1 Write your top three findings
# - The heatmap take only numeric columns from a dataframe.
# - The heatmap shows a strong positive correlation between the 'total_bill' and 'tip' variables.
# - The heatmap shows a lowest correlation between the 'size' and 'tip' variables.
